# %% [markdown]
# # This is my first Jupyter Notebook
#
# I will just list down some shortcut that will be handy for me.
# - Insert cell below: B
# - Insert cell above: A
# - Delete cell: DD (press D twice)
# - Change cell to code: Y
# - Change cell to markdown: M
# - Exit edit mode: Esc
# - Enter edit mode: Enter
# - Run cell: Ctrl + Enter
# - Clear output: Alt + del
#
# `Some code snippets for practice`

# %%
# just a simple for loop to draw pyramid of stars
for i in range(5):
    print(" " * (4 - i) + "*" * (2 * i + 1))

# %%
# simple fibonacci sequence
a, b = 0, 1
while b < 10:
    print(b)
    a, b = b, a + b

# %% [markdown]
# ## Learning Neural Networks
# From here on I am working on learning neural networks from Andrej Karpathy's youtube playlist [NEURAL NETWORKS: Zero to Hero](https://www.youtube.com/playlist?list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ)
#
# I will update the README file regarding the setup and all the necessary dependencies.
#
# 😉 Keep Learning!
